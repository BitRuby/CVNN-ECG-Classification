# %%
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import cvnn.layers as complex_layers
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from imblearn.under_sampling import RandomUnderSampler
import mlflow
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report
from tensorflow import convert_to_tensor, complex64, expand_dims
import seaborn as sns
from scipy import signal
import pywt

# %%
WINDOW_SIZE = 360
TEST_SIZE = 0.25
EPOCHS = 100
BATCH_SIZE = 128

# %%
path = "Dataset/mitbih_database"
filenames = next(os.walk(path))[2]
records=list()
annotations=list()
filenames.sort()
for f in filenames:
    filename, file_extension = os.path.splitext(f)
    if(file_extension=='.csv'):
        records.append(path+'/'+filename+file_extension)
    else:
        annotations.append(path+'/'+filename+file_extension)

# %%
def get_record_signals(index):
    signals = []
    labels = []
    with open(records[index],'r') as csvfile:
        filereader = csv.reader(csvfile,delimiter=',',quotechar='|')
        row_index = -1
        for row in filereader:
            if(row_index >= 0):
                signals.insert(row_index, int(row[1]))
            row_index += 1
        signals = np.array(signals)
    with open(annotations[index],'r') as csvfile:
        filereader = csv.reader(csvfile,delimiter=',',quotechar='|')
        row_index = -1
        for row in filereader:
            if(row_index >= 0):
                elements = list(filter(lambda x: len(x) > 0, row[0].split(" ")))
                labels.insert(row_index, [int(elements[1]), elements[2]])
            row_index += 1
        labels = np.array(labels)
    return signals, labels

# %%
def apply_detrend_and_butterworth(signals):
    fs = 360.0
    N = 650000
    T = N / fs
    t = np.linspace(0, T, N, endpoint=False)

    # Detrend (usuniecie DC/linearna składowa)
    data_detrended = signal.detrend(signals)

    # Butterworth bandpass (np. 0.5 - 40 Hz)
    lowcut = 0.5
    highcut = 40.0
    nyq = 0.5 * fs
    b, a = signal.butter(4, [lowcut/nyq, highcut/nyq], btype='band')
    data_filt = signal.filtfilt(b, a, data_detrended)  # zero-phase
    return data_filt

# %%
def compute_cwt(signal, fs=360, n_scales=32):
    freqs = np.linspace(1, 40, n_scales)

    scales = pywt.central_frequency('cmor1.5-1.0') * fs / freqs

    coeffs, freqs = pywt.cwt(
        signal,
        scales,
        'cmor1.5-1.0',
        sampling_period=1/fs
    )

    return coeffs

# %%
def zscore_per_beat(x, eps=1e-8):
    """
    Z-score normalization per beat
    """
    return (x - np.mean(x)) / (np.std(x) + eps)

# %%
def apply_welch(data):
    fs = 360.0
    nperseg = 64
    noverlap = nperseg // 2
    f_welch, Pxx = signal.welch(data, fs=fs, nperseg=nperseg, noverlap=noverlap, window='hann')
    return f_welch, Pxx

# %%
def apply_normalization(data):
    data = data[:len(data)//2]
    data = data / np.linalg.norm(data)
    return data

# %%
def process_data(window_size):
    X = []
    y = []

    half_w = window_size // 2
    valid_labels = {'A', 'L', 'N', 'R', 'V'}

    for i in range(len(records)):
        signals, labels = get_record_signals(i)
        signals = apply_detrend_and_butterworth(signals)
        sig_len = len(signals)

        mask = np.isin(labels[:, 1], list(valid_labels))
        filtered_labels = labels[mask]
        
        for j in range(3, len(filtered_labels)):
            prev_2_label_pos = int(filtered_labels[j - 2][0])
            prev_1_label_pos = int(filtered_labels[j - 1][0])
            prev_3_label_pos = int(filtered_labels[j - 3][0])
            label_pos = int(filtered_labels[j][0])
            
            RR_j_2 = prev_2_label_pos - prev_3_label_pos
            start_prev_2 = int(int(filtered_labels[j-2][0]) - 0.6 * RR_j_2)
            end_prev_2  = int(int(filtered_labels[j-2][0]) + 0.8 * RR_j_2)

            RR_j_1 = prev_1_label_pos - prev_2_label_pos
            start_prev_1 = int(int(filtered_labels[j-1][0]) - 0.6 * RR_j_1)
            end_prev_1  = int(int(filtered_labels[j-1][0]) + 0.8 * RR_j_1)
            
            RR_j = label_pos - prev_1_label_pos
            start_curr = int(int(filtered_labels[j][0]) - 0.6 * RR_j)
            end_curr  = int(int(filtered_labels[j][0]) + 0.8 * RR_j)
            

            if start_prev_2 < 0 or end_curr > sig_len:
                continue
            
            X.append(np.stack(
                # apply_normalization(compute_cwt(zscore_per_beat(signal.resample(signals[start_prev_2:end_prev_2], 256)))),
                # apply_normalization(compute_cwt(zscore_per_beat(signal.resample(signals[start_prev_1:end_prev_1], 256)))),
                apply_normalization(zscore_per_beat(signal.resample(signals[start_curr:end_curr], 256)))
            , axis=-1))
            y.append(filtered_labels[j][1])

    return X, y

# %%
X, y = process_data(window_size=WINDOW_SIZE)

# %%
# values, counts = np.unique(y, return_counts=True)
# plt.bar(values, counts)
# plt.title('Class Distribution')
# plt.xlabel('Class')
# plt.ylabel('Number of Samples')
# plt.show()

# %%
from collections import Counter

def random_undersample_indices(y, random_state=42):
    rng = np.random.default_rng(random_state)

    classes, counts = np.unique(y, return_counts=True)
    min_count = counts.min()

    indices = []
    for c in classes:
        class_idx = np.where(y == c)[0]
        sampled_idx = rng.choice(class_idx, size=min_count, replace=False)
        indices.append(sampled_idx)

    return np.concatenate(indices)

# %%
# mlflow.end_run()

# %%
for i in range(5):
    # mlflow.start_run()
    # mlflow.set_experiment("CVNN_CNN_ECG_Classification-CWT-Detrend_and_Butterworth_ComplexBatch_ZScore_RelativeWindow_v2")
    # mlflow.log_param("model", "CVNN_CONV1D-32-MaxPool2-CONV1D-32-MaxPool2-Dropout(0.1)-Dense512")
    # mlflow.log_param("input_dim", (256,16))
    # mlflow.log_param("epochs", EPOCHS)
    # mlflow.log_param("batch_size", BATCH_SIZE)
    # mlflow.log_param("optimizer", "adam")
    # mlflow.log_param("loss", "categorical_crossentropy")
    # mlflow.log_param("test_size", TEST_SIZE)
    # mlflow.log_param("scaler", "ComplexBatch ZScore")
    # mlflow.log_param("classes", "A,L,N,R,V")
    # mlflow.log_param("window_size", 256)
    
    # Train/test Split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=42)

    #Label Binarization
    lb = preprocessing.LabelBinarizer()
    y_train = lb.fit_transform(y_train)
    y_test = lb.transform(y_test)

    # # #Under sampling
    y_train_int = np.argmax(y_train, axis=1)
    idx = random_undersample_indices(y_train_int)
    X_train = np.array(X_train)[idx]
    y_train = np.array(y_train)[idx]
    
    model = Sequential()
    
    model.add(complex_layers.ComplexInput(input_shape=(128,1), name='InputLayer'))
    model.add(complex_layers.ComplexBatchNormalization())
    
    model.add(complex_layers.ComplexConv1D(32, kernel_size=5, strides = 3, activation='cart_relu'))
    model.add(complex_layers.ComplexAvgPooling1D(pool_size=2, strides = 2, dtype=np.complex64))
    model.add(complex_layers.ComplexBatchNormalization())
    
    model.add(complex_layers.ComplexConv1D(32, kernel_size=5, strides = 3, activation='cart_relu'))
    model.add(complex_layers.ComplexAvgPooling1D(pool_size=2, strides = 2, dtype=np.complex64))
    model.add(complex_layers.ComplexBatchNormalization())

    model.add(complex_layers.ComplexDropout(0.1))
    model.add(complex_layers.ComplexFlatten())
    
    model.add(complex_layers.ComplexDense(256, activation='cart_relu'))
    model.add(complex_layers.ComplexBatchNormalization())

    model.add(complex_layers.ComplexDense(5, activation='convert_to_real_with_abs', name='OutputLayer'))
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
        loss='categorical_crossentropy',
        metrics=['accuracy'])
    
    history = model.fit(X_train, y_train, epochs=EPOCHS)
    
    X_test_tf = convert_to_tensor(X_test, dtype=complex64)
    y_test_tf = convert_to_tensor(y_test)
    # X_test_tf = expand_dims(X_test_tf, axis=-1)

    y_pred = np.argmax(model.predict(X_test_tf), axis=1)
    y_true = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(y_true, y_pred)

    precision, recall, f1, support = precision_recall_fscore_support(
        y_true, y_pred, average=None
    )

    precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(
        y_true, y_pred, average="macro"
    )

    precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(
        y_true, y_pred, average="weighted"
    )

    # mlflow.log_metric("accuracy", accuracy)

    # mlflow.log_metric("precision_macro", precision_macro)
    # mlflow.log_metric("recall_macro", recall_macro)
    # mlflow.log_metric("f1_macro", f1_macro)

    # mlflow.log_metric("precision_weighted", precision_weighted)
    # mlflow.log_metric("recall_weighted", recall_weighted)
    # mlflow.log_metric("f1_weighted", f1_weighted)

    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(7, 6))
    sns.heatmap(
        cm_norm,
        annot=True,
        fmt=".2f",
        cmap="Blues"
    )
    plt.title("Normalized Confusion Matrix")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

    plt.tight_layout()
    plt.savefig("confusion_matrix.png")
    plt.close()

    # mlflow.log_artifact("confusion_matrix.png")
    # report = classification_report(y_true, y_pred)
    # with open("classification_report.txt", "w") as f:
    #     f.write(report)
    # mlflow.log_artifact("classification_report.txt")
    # mlflow.end_run()
# Out:
# Epoch 1/100
# 307/307 [==============================] - 19s 34ms/step - loss: 0.7947 - accuracy: 0.8360
# Epoch 2/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.5470 - accuracy: 0.9201
# Epoch 3/100
# 307/307 [==============================] - 11s 37ms/step - loss: 0.4690 - accuracy: 0.9298
# Epoch 4/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.4201 - accuracy: 0.9412
# Epoch 5/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.3921 - accuracy: 0.9439
# Epoch 6/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.3843 - accuracy: 0.9438
# Epoch 7/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.3471 - accuracy: 0.9498
# Epoch 8/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.3483 - accuracy: 0.9499
# Epoch 9/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.3252 - accuracy: 0.9542
# Epoch 10/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.3182 - accuracy: 0.9532
# Epoch 11/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.2964 - accuracy: 0.9583
# Epoch 12/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2902 - accuracy: 0.9586
# Epoch 13/100
# 307/307 [==============================] - 11s 34ms/step - loss: 0.2979 - accuracy: 0.9559
# Epoch 14/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.3019 - accuracy: 0.9566
# Epoch 15/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.2810 - accuracy: 0.9596
# Epoch 16/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.2719 - accuracy: 0.9576
# Epoch 17/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.2562 - accuracy: 0.9628
# Epoch 18/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.2508 - accuracy: 0.9658
# Epoch 19/100
# 307/307 [==============================] - 11s 34ms/step - loss: 0.2476 - accuracy: 0.9662
# Epoch 20/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.2632 - accuracy: 0.9623
# Epoch 21/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.2661 - accuracy: 0.9603
# Epoch 22/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.2531 - accuracy: 0.9653
# Epoch 23/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2314 - accuracy: 0.9673
# Epoch 24/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2566 - accuracy: 0.9635
# Epoch 25/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.2369 - accuracy: 0.9668
# Epoch 26/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2316 - accuracy: 0.9674
# Epoch 27/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.2418 - accuracy: 0.9651
# Epoch 28/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.2229 - accuracy: 0.9702
# Epoch 29/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2252 - accuracy: 0.9697
# Epoch 30/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2593 - accuracy: 0.9578
# Epoch 31/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.2367 - accuracy: 0.9627
# Epoch 32/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.2178 - accuracy: 0.9691
# Epoch 33/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.2151 - accuracy: 0.9702
# Epoch 34/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.2131 - accuracy: 0.9716
# Epoch 35/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.2081 - accuracy: 0.9726
# Epoch 36/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.2071 - accuracy: 0.9718
# Epoch 37/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.2119 - accuracy: 0.9710
# Epoch 38/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.2226 - accuracy: 0.9696
# Epoch 39/100
# 307/307 [==============================] - 11s 37ms/step - loss: 0.2174 - accuracy: 0.9683
# Epoch 40/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.2011 - accuracy: 0.9733
# Epoch 41/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.1965 - accuracy: 0.9738
# Epoch 42/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.1976 - accuracy: 0.9743
# Epoch 43/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1986 - accuracy: 0.9726
# Epoch 44/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.2012 - accuracy: 0.9729
# Epoch 45/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.1913 - accuracy: 0.9726
# Epoch 46/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.2028 - accuracy: 0.9737
# Epoch 47/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1947 - accuracy: 0.9740
# Epoch 48/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1857 - accuracy: 0.9767
# Epoch 49/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1900 - accuracy: 0.9743
# Epoch 50/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1826 - accuracy: 0.9774
# Epoch 51/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1840 - accuracy: 0.9756
# Epoch 52/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1790 - accuracy: 0.9774
# Epoch 53/100
# 307/307 [==============================] - 11s 37ms/step - loss: 0.1820 - accuracy: 0.9769
# Epoch 54/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.1977 - accuracy: 0.9742
# Epoch 55/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1823 - accuracy: 0.9755
# Epoch 56/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.1914 - accuracy: 0.9739
# Epoch 57/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1857 - accuracy: 0.9756
# Epoch 58/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.1950 - accuracy: 0.9724
# Epoch 59/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1947 - accuracy: 0.9740
# Epoch 60/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1886 - accuracy: 0.9762
# Epoch 61/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1732 - accuracy: 0.9787
# Epoch 62/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1737 - accuracy: 0.9779
# Epoch 63/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1676 - accuracy: 0.9812
# Epoch 64/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1799 - accuracy: 0.9773
# Epoch 65/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1858 - accuracy: 0.9751
# Epoch 66/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1656 - accuracy: 0.9793
# Epoch 67/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1757 - accuracy: 0.9758
# Epoch 68/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1670 - accuracy: 0.9806
# Epoch 69/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1713 - accuracy: 0.9783
# Epoch 70/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1652 - accuracy: 0.9803
# Epoch 71/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1686 - accuracy: 0.9806
# Epoch 72/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.1694 - accuracy: 0.9786
# Epoch 73/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1617 - accuracy: 0.9807
# Epoch 74/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1651 - accuracy: 0.9802
# Epoch 75/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1674 - accuracy: 0.9807
# Epoch 76/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1567 - accuracy: 0.9825
# Epoch 77/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1618 - accuracy: 0.9800
# Epoch 78/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1784 - accuracy: 0.9767
# Epoch 79/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1808 - accuracy: 0.9754
# Epoch 80/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1648 - accuracy: 0.9791
# Epoch 81/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1577 - accuracy: 0.9807
# Epoch 82/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1593 - accuracy: 0.9803
# Epoch 83/100
# 307/307 [==============================] - 11s 34ms/step - loss: 0.1626 - accuracy: 0.9796
# Epoch 84/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1610 - accuracy: 0.9813
# Epoch 85/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1568 - accuracy: 0.9828
# Epoch 86/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1604 - accuracy: 0.9800
# Epoch 87/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1628 - accuracy: 0.9796
# Epoch 88/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1574 - accuracy: 0.9827
# Epoch 89/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1559 - accuracy: 0.9817
# Epoch 90/100
# 307/307 [==============================] - 11s 34ms/step - loss: 0.1567 - accuracy: 0.9820
# Epoch 91/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.1570 - accuracy: 0.9819
# Epoch 92/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1550 - accuracy: 0.9819
# Epoch 93/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.1499 - accuracy: 0.9838
# Epoch 94/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.1502 - accuracy: 0.9822
# Epoch 95/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.1562 - accuracy: 0.9814
# Epoch 96/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1706 - accuracy: 0.9781
# Epoch 97/100
# 307/307 [==============================] - 11s 37ms/step - loss: 0.1523 - accuracy: 0.9818
# Epoch 98/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.1551 - accuracy: 0.9801
# Epoch 99/100
# 307/307 [==============================] - 11s 37ms/step - loss: 0.1543 - accuracy: 0.9826
# Epoch 100/100
# 307/307 [==============================] - 11s 37ms/step - loss: 0.1528 - accuracy: 0.9808
# 781/781 [==============================] - 9s 11ms/step
# Epoch 1/100
# 307/307 [==============================] - 16s 37ms/step - loss: 0.7576 - accuracy: 0.8456
# Epoch 2/100
# 307/307 [==============================] - 11s 36ms/step - loss: 0.5356 - accuracy: 0.9181
# Epoch 3/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.4587 - accuracy: 0.9334
# Epoch 4/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.4213 - accuracy: 0.9361
# Epoch 5/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.3884 - accuracy: 0.9464
# Epoch 6/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.4111 - accuracy: 0.9392
# Epoch 7/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.3656 - accuracy: 0.9518
# Epoch 8/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.3361 - accuracy: 0.9538
# Epoch 9/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.3311 - accuracy: 0.9524
# Epoch 10/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.3179 - accuracy: 0.9544
# Epoch 11/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.3195 - accuracy: 0.9538
# Epoch 12/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.3018 - accuracy: 0.9573
# Epoch 13/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2895 - accuracy: 0.9604
# Epoch 14/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2792 - accuracy: 0.9613
# Epoch 15/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2769 - accuracy: 0.9615
# Epoch 16/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2648 - accuracy: 0.9639
# Epoch 17/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2585 - accuracy: 0.9642
# Epoch 18/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2844 - accuracy: 0.9584
# Epoch 19/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2591 - accuracy: 0.9630
# Epoch 20/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2538 - accuracy: 0.9666
# Epoch 21/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2383 - accuracy: 0.9689
# Epoch 22/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2443 - accuracy: 0.9655
# Epoch 23/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2326 - accuracy: 0.9705
# Epoch 24/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2313 - accuracy: 0.9686
# Epoch 25/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2309 - accuracy: 0.9682
# Epoch 26/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2271 - accuracy: 0.9686
# Epoch 27/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2171 - accuracy: 0.9718
# Epoch 28/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2198 - accuracy: 0.9679
# Epoch 29/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2150 - accuracy: 0.9721
# Epoch 30/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2131 - accuracy: 0.9720
# Epoch 31/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2107 - accuracy: 0.9711
# Epoch 32/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2151 - accuracy: 0.9702
# Epoch 33/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2233 - accuracy: 0.9686
# Epoch 34/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2125 - accuracy: 0.9712
# Epoch 35/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.2159 - accuracy: 0.9695
# Epoch 36/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2049 - accuracy: 0.9724
# Epoch 37/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1991 - accuracy: 0.9728
# Epoch 38/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2071 - accuracy: 0.9724
# Epoch 39/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1921 - accuracy: 0.9745
# Epoch 40/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1999 - accuracy: 0.9736
# Epoch 41/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1904 - accuracy: 0.9748
# Epoch 42/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2012 - accuracy: 0.9751
# Epoch 43/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1881 - accuracy: 0.9765
# Epoch 44/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1915 - accuracy: 0.9752
# Epoch 45/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1933 - accuracy: 0.9753
# Epoch 46/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2231 - accuracy: 0.9684
# Epoch 47/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2401 - accuracy: 0.9681
# Epoch 48/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2046 - accuracy: 0.9734
# Epoch 49/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2033 - accuracy: 0.9750
# Epoch 50/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1889 - accuracy: 0.9756
# Epoch 51/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1937 - accuracy: 0.9737
# Epoch 52/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1915 - accuracy: 0.9755
# Epoch 53/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.1860 - accuracy: 0.9772
# Epoch 54/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1839 - accuracy: 0.9771
# Epoch 55/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1942 - accuracy: 0.9713
# Epoch 56/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1824 - accuracy: 0.9755
# Epoch 57/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1844 - accuracy: 0.9766
# Epoch 58/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1754 - accuracy: 0.9773
# Epoch 59/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1892 - accuracy: 0.9751
# Epoch 60/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1960 - accuracy: 0.9749
# Epoch 61/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1784 - accuracy: 0.9792
# Epoch 62/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1743 - accuracy: 0.9796
# Epoch 63/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1741 - accuracy: 0.9794
# Epoch 64/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1852 - accuracy: 0.9772
# Epoch 65/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1702 - accuracy: 0.9779
# Epoch 66/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1747 - accuracy: 0.9781
# Epoch 67/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1704 - accuracy: 0.9796
# Epoch 68/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1697 - accuracy: 0.9795
# Epoch 69/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1711 - accuracy: 0.9814
# Epoch 70/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1711 - accuracy: 0.9805
# Epoch 71/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1718 - accuracy: 0.9806
# Epoch 72/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1696 - accuracy: 0.9797
# Epoch 73/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1719 - accuracy: 0.9790
# Epoch 74/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1654 - accuracy: 0.9816
# Epoch 75/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1795 - accuracy: 0.9758
# Epoch 76/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1696 - accuracy: 0.9793
# Epoch 77/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1692 - accuracy: 0.9801
# Epoch 78/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2062 - accuracy: 0.9698
# Epoch 79/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.1780 - accuracy: 0.9781
# Epoch 80/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1657 - accuracy: 0.9795
# Epoch 81/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1659 - accuracy: 0.9784
# Epoch 82/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1668 - accuracy: 0.9792
# Epoch 83/100
# 307/307 [==============================] - 11s 34ms/step - loss: 0.1729 - accuracy: 0.9806
# Epoch 84/100
# 307/307 [==============================] - 11s 35ms/step - loss: 0.1553 - accuracy: 0.9816
# Epoch 85/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1611 - accuracy: 0.9806
# Epoch 86/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1621 - accuracy: 0.9820
# Epoch 87/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2061 - accuracy: 0.9727
# Epoch 88/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1855 - accuracy: 0.9773
# Epoch 89/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1695 - accuracy: 0.9801
# Epoch 90/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1771 - accuracy: 0.9765
# Epoch 91/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1683 - accuracy: 0.9795
# Epoch 92/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1667 - accuracy: 0.9814
# Epoch 93/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1643 - accuracy: 0.9804
# Epoch 94/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1663 - accuracy: 0.9784
# Epoch 95/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1604 - accuracy: 0.9807
# Epoch 96/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1545 - accuracy: 0.9817
# Epoch 97/100
# 307/307 [==============================] - 11s 34ms/step - loss: 0.1589 - accuracy: 0.9806
# Epoch 98/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1563 - accuracy: 0.9807
# Epoch 99/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1561 - accuracy: 0.9822
# Epoch 100/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1591 - accuracy: 0.9818
# 781/781 [==============================] - 8s 10ms/step
# Epoch 1/100
# 307/307 [==============================] - 14s 33ms/step - loss: 0.7677 - accuracy: 0.8523
# Epoch 2/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.5434 - accuracy: 0.9228
# Epoch 3/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.4642 - accuracy: 0.9401
# Epoch 4/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.4305 - accuracy: 0.9403
# Epoch 5/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.3917 - accuracy: 0.9474
# Epoch 6/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.3669 - accuracy: 0.9510
# Epoch 7/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.3357 - accuracy: 0.9562
# Epoch 8/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.3339 - accuracy: 0.9545
# Epoch 9/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.3383 - accuracy: 0.9524
# Epoch 10/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.3156 - accuracy: 0.9530
# Epoch 11/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.3059 - accuracy: 0.9532
# Epoch 12/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.3370 - accuracy: 0.9462
# Epoch 13/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.3285 - accuracy: 0.9445
# Epoch 14/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2902 - accuracy: 0.9531
# Epoch 15/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2805 - accuracy: 0.9565
# Epoch 16/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2730 - accuracy: 0.9582
# Epoch 17/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2688 - accuracy: 0.9570
# Epoch 18/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2598 - accuracy: 0.9613
# Epoch 19/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2525 - accuracy: 0.9629
# Epoch 20/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2484 - accuracy: 0.9640
# Epoch 21/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2421 - accuracy: 0.9654
# Epoch 22/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2391 - accuracy: 0.9642
# Epoch 23/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2481 - accuracy: 0.9612
# Epoch 24/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2402 - accuracy: 0.9646
# Epoch 25/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2278 - accuracy: 0.9675
# Epoch 26/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2286 - accuracy: 0.9656
# Epoch 27/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2290 - accuracy: 0.9688
# Epoch 28/100
# 307/307 [==============================] - 11s 34ms/step - loss: 0.2276 - accuracy: 0.9662
# Epoch 29/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2250 - accuracy: 0.9657
# Epoch 30/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2259 - accuracy: 0.9675
# Epoch 31/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2424 - accuracy: 0.9663
# Epoch 32/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2122 - accuracy: 0.9722
# Epoch 33/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.2128 - accuracy: 0.9697
# Epoch 34/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2297 - accuracy: 0.9641
# Epoch 35/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2062 - accuracy: 0.9716
# Epoch 36/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2344 - accuracy: 0.9678
# Epoch 37/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2153 - accuracy: 0.9674
# Epoch 38/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2087 - accuracy: 0.9716
# Epoch 39/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2118 - accuracy: 0.9694
# Epoch 40/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.2067 - accuracy: 0.9727
# Epoch 41/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2028 - accuracy: 0.9737
# Epoch 42/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1960 - accuracy: 0.9762
# Epoch 43/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2026 - accuracy: 0.9744
# Epoch 44/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2082 - accuracy: 0.9720
# Epoch 45/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2030 - accuracy: 0.9736
# Epoch 46/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1906 - accuracy: 0.9766
# Epoch 47/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1864 - accuracy: 0.9779
# Epoch 48/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1966 - accuracy: 0.9743
# Epoch 49/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2162 - accuracy: 0.9691
# Epoch 50/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1964 - accuracy: 0.9745
# Epoch 51/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1966 - accuracy: 0.9729
# Epoch 52/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1904 - accuracy: 0.9749
# Epoch 53/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1970 - accuracy: 0.9742
# Epoch 54/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1940 - accuracy: 0.9748
# Epoch 55/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1816 - accuracy: 0.9772
# Epoch 56/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1837 - accuracy: 0.9761
# Epoch 57/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1803 - accuracy: 0.9773
# Epoch 58/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1751 - accuracy: 0.9781
# Epoch 59/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1779 - accuracy: 0.9786
# Epoch 60/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1803 - accuracy: 0.9771
# Epoch 61/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1825 - accuracy: 0.9747
# Epoch 62/100
# 307/307 [==============================] - 10s 34ms/step - loss: 0.1877 - accuracy: 0.9749
# Epoch 63/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1738 - accuracy: 0.9781
# Epoch 64/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1779 - accuracy: 0.9773
# Epoch 65/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.1771 - accuracy: 0.9788
# Epoch 66/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.1718 - accuracy: 0.9802
# Epoch 67/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1718 - accuracy: 0.9793
# Epoch 68/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1838 - accuracy: 0.9773
# Epoch 69/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1669 - accuracy: 0.9792
# Epoch 70/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1689 - accuracy: 0.9809
# Epoch 71/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.1772 - accuracy: 0.9778
# Epoch 72/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1972 - accuracy: 0.9727
# Epoch 73/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1826 - accuracy: 0.9748
# Epoch 74/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1716 - accuracy: 0.9797
# Epoch 75/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1771 - accuracy: 0.9767
# Epoch 76/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1679 - accuracy: 0.9808
# Epoch 77/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1677 - accuracy: 0.9789
# Epoch 78/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1669 - accuracy: 0.9803
# Epoch 79/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1663 - accuracy: 0.9809
# Epoch 80/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.1642 - accuracy: 0.9796
# Epoch 81/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.1640 - accuracy: 0.9803
# Epoch 82/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1639 - accuracy: 0.9808
# Epoch 83/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1728 - accuracy: 0.9778
# Epoch 84/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1728 - accuracy: 0.9772
# Epoch 85/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1680 - accuracy: 0.9800
# Epoch 86/100
# 307/307 [==============================] - 8s 27ms/step - loss: 0.1654 - accuracy: 0.9793
# Epoch 87/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1608 - accuracy: 0.9800
# Epoch 88/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1643 - accuracy: 0.9810
# Epoch 89/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1613 - accuracy: 0.9804
# Epoch 90/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1753 - accuracy: 0.9777
# Epoch 91/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1621 - accuracy: 0.9797
# Epoch 92/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1541 - accuracy: 0.9818
# Epoch 93/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1608 - accuracy: 0.9812
# Epoch 94/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1662 - accuracy: 0.9786
# Epoch 95/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.1634 - accuracy: 0.9805
# Epoch 96/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.1701 - accuracy: 0.9806
# Epoch 97/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1544 - accuracy: 0.9817
# Epoch 98/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1506 - accuracy: 0.9837
# Epoch 99/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1620 - accuracy: 0.9788
# Epoch 100/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1545 - accuracy: 0.9812
# 781/781 [==============================] - 8s 9ms/step
# Epoch 1/100
# 307/307 [==============================] - 13s 30ms/step - loss: 0.7365 - accuracy: 0.8574
# Epoch 2/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.5309 - accuracy: 0.9204
# Epoch 3/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.4675 - accuracy: 0.9322
# Epoch 4/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.4032 - accuracy: 0.9422
# Epoch 5/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.3728 - accuracy: 0.9472
# Epoch 6/100
# 307/307 [==============================] - 9s 31ms/step - loss: 0.3539 - accuracy: 0.9491
# Epoch 7/100
# 307/307 [==============================] - 9s 31ms/step - loss: 0.3387 - accuracy: 0.9515
# Epoch 8/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.3176 - accuracy: 0.9567
# Epoch 9/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.3209 - accuracy: 0.9557
# Epoch 10/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.3040 - accuracy: 0.9589
# Epoch 11/100
# 307/307 [==============================] - 9s 31ms/step - loss: 0.2925 - accuracy: 0.9598
# Epoch 12/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2874 - accuracy: 0.9617
# Epoch 13/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2786 - accuracy: 0.9609
# Epoch 14/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.2648 - accuracy: 0.9647
# Epoch 15/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.2648 - accuracy: 0.9655
# Epoch 16/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.2662 - accuracy: 0.9625
# Epoch 17/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2487 - accuracy: 0.9652
# Epoch 18/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2477 - accuracy: 0.9671
# Epoch 19/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2714 - accuracy: 0.9640
# Epoch 20/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2466 - accuracy: 0.9659
# Epoch 21/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.2535 - accuracy: 0.9664
# Epoch 22/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.2603 - accuracy: 0.9610
# Epoch 23/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.2325 - accuracy: 0.9697
# Epoch 24/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.2372 - accuracy: 0.9658
# Epoch 25/100
# 307/307 [==============================] - 9s 31ms/step - loss: 0.2320 - accuracy: 0.9688
# Epoch 26/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.2201 - accuracy: 0.9720
# Epoch 27/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2184 - accuracy: 0.9727
# Epoch 28/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.2357 - accuracy: 0.9710
# Epoch 29/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2185 - accuracy: 0.9719
# Epoch 30/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.2183 - accuracy: 0.9714
# Epoch 31/100
# 307/307 [==============================] - 9s 31ms/step - loss: 0.2060 - accuracy: 0.9729
# Epoch 32/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.2083 - accuracy: 0.9741
# Epoch 33/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.2098 - accuracy: 0.9733
# Epoch 34/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2067 - accuracy: 0.9730
# Epoch 35/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2139 - accuracy: 0.9710
# Epoch 36/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.2104 - accuracy: 0.9724
# Epoch 37/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2018 - accuracy: 0.9724
# Epoch 38/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1977 - accuracy: 0.9750
# Epoch 39/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2004 - accuracy: 0.9743
# Epoch 40/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1902 - accuracy: 0.9750
# Epoch 41/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1945 - accuracy: 0.9768
# Epoch 42/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1950 - accuracy: 0.9758
# Epoch 43/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1918 - accuracy: 0.9768
# Epoch 44/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1835 - accuracy: 0.9767
# Epoch 45/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1899 - accuracy: 0.9761
# Epoch 46/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1859 - accuracy: 0.9792
# Epoch 47/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1821 - accuracy: 0.9766
# Epoch 48/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1888 - accuracy: 0.9760
# Epoch 49/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1885 - accuracy: 0.9771
# Epoch 50/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1832 - accuracy: 0.9775
# Epoch 51/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1813 - accuracy: 0.9795
# Epoch 52/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1796 - accuracy: 0.9783
# Epoch 53/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1853 - accuracy: 0.9763
# Epoch 54/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.2021 - accuracy: 0.9715
# Epoch 55/100
# 307/307 [==============================] - 9s 31ms/step - loss: 0.2048 - accuracy: 0.9704
# Epoch 56/100
# 307/307 [==============================] - 10s 32ms/step - loss: 0.1869 - accuracy: 0.9745
# Epoch 57/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1815 - accuracy: 0.9772
# Epoch 58/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1728 - accuracy: 0.9802
# Epoch 59/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1737 - accuracy: 0.9790
# Epoch 60/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1759 - accuracy: 0.9774
# Epoch 61/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1701 - accuracy: 0.9791
# Epoch 62/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.1719 - accuracy: 0.9794
# Epoch 63/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1777 - accuracy: 0.9774
# Epoch 64/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1896 - accuracy: 0.9751
# Epoch 65/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1744 - accuracy: 0.9797
# Epoch 66/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1650 - accuracy: 0.9806
# Epoch 67/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1696 - accuracy: 0.9801
# Epoch 68/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1649 - accuracy: 0.9794
# Epoch 69/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1727 - accuracy: 0.9782
# Epoch 70/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1649 - accuracy: 0.9820
# Epoch 71/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.1749 - accuracy: 0.9798
# Epoch 72/100
# 307/307 [==============================] - 10s 33ms/step - loss: 0.1668 - accuracy: 0.9785
# Epoch 73/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1646 - accuracy: 0.9807
# Epoch 74/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1591 - accuracy: 0.9807
# Epoch 75/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1680 - accuracy: 0.9792
# Epoch 76/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1666 - accuracy: 0.9798
# Epoch 77/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1684 - accuracy: 0.9794
# Epoch 78/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1660 - accuracy: 0.9812
# Epoch 79/100
# 307/307 [==============================] - 8s 28ms/step - loss: 0.1677 - accuracy: 0.9801
# Epoch 80/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1677 - accuracy: 0.9795
# Epoch 81/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1655 - accuracy: 0.9823
# Epoch 82/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1603 - accuracy: 0.9812
# Epoch 83/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1584 - accuracy: 0.9823
# Epoch 84/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1562 - accuracy: 0.9815
# Epoch 85/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1544 - accuracy: 0.9837
# Epoch 86/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1573 - accuracy: 0.9812
# Epoch 87/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1592 - accuracy: 0.9815
# Epoch 88/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1578 - accuracy: 0.9827
# Epoch 89/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1522 - accuracy: 0.9838
# Epoch 90/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1527 - accuracy: 0.9835
# Epoch 91/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1511 - accuracy: 0.9832
# Epoch 92/100
# 307/307 [==============================] - 8s 28ms/step - loss: 0.1566 - accuracy: 0.9825
# Epoch 93/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1537 - accuracy: 0.9810
# Epoch 94/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1532 - accuracy: 0.9834
# Epoch 95/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1570 - accuracy: 0.9822
# Epoch 96/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1525 - accuracy: 0.9807
# Epoch 97/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1506 - accuracy: 0.9842
# Epoch 98/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1542 - accuracy: 0.9833
# Epoch 99/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1511 - accuracy: 0.9837
# Epoch 100/100
# 307/307 [==============================] - 9s 28ms/step - loss: 0.1575 - accuracy: 0.9833
# 781/781 [==============================] - 8s 9ms/step
# Epoch 1/100
# 307/307 [==============================] - 13s 30ms/step - loss: 0.8260 - accuracy: 0.8328
# Epoch 2/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.5679 - accuracy: 0.9096
# Epoch 3/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.4911 - accuracy: 0.9287
# Epoch 4/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.4403 - accuracy: 0.9379
# Epoch 5/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.3995 - accuracy: 0.9415
# Epoch 6/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.3890 - accuracy: 0.9434
# Epoch 7/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.3677 - accuracy: 0.9469
# Epoch 8/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.3561 - accuracy: 0.9494
# Epoch 9/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.3335 - accuracy: 0.9531
# Epoch 10/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.3249 - accuracy: 0.9539
# Epoch 11/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.3056 - accuracy: 0.9562
# Epoch 12/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.3046 - accuracy: 0.9561
# Epoch 13/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2873 - accuracy: 0.9590
# Epoch 14/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.3047 - accuracy: 0.9561
# Epoch 15/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.3419 - accuracy: 0.9462
# Epoch 16/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2922 - accuracy: 0.9565
# Epoch 17/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2791 - accuracy: 0.9599
# Epoch 18/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.2687 - accuracy: 0.9617
# Epoch 19/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2555 - accuracy: 0.9654
# Epoch 20/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2594 - accuracy: 0.9638
# Epoch 21/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2475 - accuracy: 0.9658
# Epoch 22/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2520 - accuracy: 0.9675
# Epoch 23/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.2688 - accuracy: 0.9610
# Epoch 24/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2450 - accuracy: 0.9667
# Epoch 25/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2362 - accuracy: 0.9678
# Epoch 26/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2337 - accuracy: 0.9695
# Epoch 27/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2291 - accuracy: 0.9669
# Epoch 28/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2196 - accuracy: 0.9705
# Epoch 29/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.2300 - accuracy: 0.9683
# Epoch 30/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2166 - accuracy: 0.9711
# Epoch 31/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2144 - accuracy: 0.9700
# Epoch 32/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2182 - accuracy: 0.9697
# Epoch 33/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2140 - accuracy: 0.9721
# Epoch 34/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2056 - accuracy: 0.9714
# Epoch 35/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2147 - accuracy: 0.9719
# Epoch 36/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2149 - accuracy: 0.9719
# Epoch 37/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.2051 - accuracy: 0.9718
# Epoch 38/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2038 - accuracy: 0.9728
# Epoch 39/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2006 - accuracy: 0.9742
# Epoch 40/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2170 - accuracy: 0.9732
# Epoch 41/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2052 - accuracy: 0.9709
# Epoch 42/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2360 - accuracy: 0.9648
# Epoch 43/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2111 - accuracy: 0.9714
# Epoch 44/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.2035 - accuracy: 0.9712
# Epoch 45/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1898 - accuracy: 0.9760
# Epoch 46/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1914 - accuracy: 0.9721
# Epoch 47/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1861 - accuracy: 0.9774
# Epoch 48/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1914 - accuracy: 0.9769
# Epoch 49/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1935 - accuracy: 0.9751
# Epoch 50/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1858 - accuracy: 0.9761
# Epoch 51/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1827 - accuracy: 0.9776
# Epoch 52/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1813 - accuracy: 0.9772
# Epoch 53/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1843 - accuracy: 0.9770
# Epoch 54/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1839 - accuracy: 0.9769
# Epoch 55/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1751 - accuracy: 0.9780
# Epoch 56/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1789 - accuracy: 0.9781
# Epoch 57/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1901 - accuracy: 0.9753
# Epoch 58/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1921 - accuracy: 0.9762
# Epoch 59/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1855 - accuracy: 0.9785
# Epoch 60/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1831 - accuracy: 0.9779
# Epoch 61/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1798 - accuracy: 0.9769
# Epoch 62/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1838 - accuracy: 0.9763
# Epoch 63/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1715 - accuracy: 0.9795
# Epoch 64/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1679 - accuracy: 0.9793
# Epoch 65/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1799 - accuracy: 0.9788
# Epoch 66/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1706 - accuracy: 0.9799
# Epoch 67/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1736 - accuracy: 0.9778
# Epoch 68/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1634 - accuracy: 0.9810
# Epoch 69/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1736 - accuracy: 0.9799
# Epoch 70/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1793 - accuracy: 0.9778
# Epoch 71/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1735 - accuracy: 0.9802
# Epoch 72/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1697 - accuracy: 0.9792
# Epoch 73/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1680 - accuracy: 0.9794
# Epoch 74/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1622 - accuracy: 0.9814
# Epoch 75/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1789 - accuracy: 0.9775
# Epoch 76/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1709 - accuracy: 0.9788
# Epoch 77/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1633 - accuracy: 0.9804
# Epoch 78/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1897 - accuracy: 0.9751
# Epoch 79/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1698 - accuracy: 0.9803
# Epoch 80/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1591 - accuracy: 0.9828
# Epoch 81/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1760 - accuracy: 0.9764
# Epoch 82/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1680 - accuracy: 0.9798
# Epoch 83/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1653 - accuracy: 0.9808
# Epoch 84/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1603 - accuracy: 0.9818
# Epoch 85/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1596 - accuracy: 0.9828
# Epoch 86/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1629 - accuracy: 0.9796
# Epoch 87/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1654 - accuracy: 0.9808
# Epoch 88/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1622 - accuracy: 0.9796
# Epoch 89/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1576 - accuracy: 0.9822
# Epoch 90/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1534 - accuracy: 0.9831
# Epoch 91/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1617 - accuracy: 0.9818
# Epoch 92/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1539 - accuracy: 0.9830
# Epoch 93/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1597 - accuracy: 0.9821
# Epoch 94/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1612 - accuracy: 0.9824
# Epoch 95/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1603 - accuracy: 0.9830
# Epoch 96/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1541 - accuracy: 0.9812
# Epoch 97/100
# 307/307 [==============================] - 10s 31ms/step - loss: 0.1615 - accuracy: 0.9805
# Epoch 98/100
# 307/307 [==============================] - 9s 30ms/step - loss: 0.1608 - accuracy: 0.9810
# Epoch 99/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1589 - accuracy: 0.9823
# Epoch 100/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1600 - accuracy: 0.9826
# 781/781 [==============================] - 9s 11ms/step

# %%
experiment_name = "CVNN_CNN_ECG_Classification-CWT-Detrend_and_Butterworth_ComplexBatch_ZScore_RelativeWindow_v2"

runs = mlflow.search_runs(
    experiment_names=[experiment_name],
    output_format="pandas"
)

summary = (
    runs
    .groupby(["params.window_size", "params.epochs", "params.model"])
    .agg(
        accuracy_mean=("metrics.accuracy", "mean"),
        accuracy_std=("metrics.accuracy", "std"),
        f1_macro_mean=("metrics.f1_macro", "mean"),
        f1_macro_std=("metrics.f1_macro", "std"),
    )
    .reset_index()
)

print(summary)
# Out:
# c:\Users\micha\anaconda32\lib\site-packages\mlflow\tracking\_tracking_service\utils.py:140: FutureWarning: Filesystem tracking backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri, store_uri)
#   params.window_size params.epochs  \
# 0                256           100
#
#                                         params.model  accuracy_mean  \
# 0  CVNN_CONV1D-32-MaxPool2-CONV1D-32-MaxPool2-Dro...       0.968434
#
#    accuracy_std  f1_macro_mean  f1_macro_std
# 0      0.001599       0.920085      0.001972
