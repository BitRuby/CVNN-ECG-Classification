# %%
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import cvnn.layers as complex_layers
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from imblearn.under_sampling import RandomUnderSampler
import mlflow
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report
from tensorflow import convert_to_tensor, complex64, expand_dims
import seaborn as sns
from scipy import signal

# %%
WINDOW_SIZE = 360
TEST_SIZE = 0.25
EPOCHS = 100
BATCH_SIZE = 128

# %%
path = "Dataset/mitbih_database"
filenames = next(os.walk(path))[2]
records=list()
annotations=list()
filenames.sort()
for f in filenames:
    filename, file_extension = os.path.splitext(f)
    if(file_extension=='.csv'):
        records.append(path+'/'+filename+file_extension)
    else:
        annotations.append(path+'/'+filename+file_extension)

# %%
def get_record_signals(index):
    signals = []
    labels = []
    with open(records[index],'r') as csvfile:
        filereader = csv.reader(csvfile,delimiter=',',quotechar='|')
        row_index = -1
        for row in filereader:
            if(row_index >= 0):
                signals.insert(row_index, int(row[1]))
            row_index += 1
        signals = np.array(signals)
    with open(annotations[index],'r') as csvfile:
        filereader = csv.reader(csvfile,delimiter=',',quotechar='|')
        row_index = -1
        for row in filereader:
            if(row_index >= 0):
                elements = list(filter(lambda x: len(x) > 0, row[0].split(" ")))
                labels.insert(row_index, [int(elements[1]), elements[2]])
            row_index += 1
        labels = np.array(labels)
    return signals, labels

# %%
def apply_detrend_and_butterworth(signals):
    fs = 360.0
    N = 650000
    T = N / fs
    t = np.linspace(0, T, N, endpoint=False)

    # Detrend (usuniecie DC/linearna składowa)
    data_detrended = signal.detrend(signals)

    # Butterworth bandpass (np. 0.5 - 40 Hz)
    lowcut = 0.5
    highcut = 40.0
    nyq = 0.5 * fs
    b, a = signal.butter(4, [lowcut/nyq, highcut/nyq], btype='band')
    data_filt = signal.filtfilt(b, a, data_detrended)  # zero-phase
    return data_filt

# %%
def zscore_per_beat(x, eps=1e-8):
    """
    Z-score normalization per beat
    """
    return (x - np.mean(x)) / (np.std(x) + eps)

# %%
def apply_welch(data):
    fs = 360.0
    nperseg = 64
    noverlap = nperseg // 2
    f_welch, Pxx = signal.welch(data, fs=fs, nperseg=nperseg, noverlap=noverlap, window='hann')
    return f_welch, Pxx

# %%
def apply_normalization(data):
    data = data[:len(data)//2]
    data = data / np.linalg.norm(data)
    return data

# %%
def process_data(window_size):
    X = []
    y = []

    half_w = window_size // 2
    valid_labels = {'A', 'L', 'N', 'R', 'V'}

    for i in range(len(records)):
        signals, labels = get_record_signals(i)
        signals = apply_detrend_and_butterworth(signals)
        sig_len = len(signals)

        mask = np.isin(labels[:, 1], list(valid_labels))
        filtered_labels = labels[mask]
        
        for j in range(3, len(filtered_labels)):
            prev_2_label_pos = int(filtered_labels[j - 2][0])
            prev_1_label_pos = int(filtered_labels[j - 1][0])
            prev_3_label_pos = int(filtered_labels[j - 3][0])
            label_pos = int(filtered_labels[j][0])
            
            RR_j_2 = prev_2_label_pos - prev_3_label_pos
            start_prev_2 = int(int(filtered_labels[j-2][0]) - 0.6 * RR_j_2)
            end_prev_2  = int(int(filtered_labels[j-2][0]) + 0.8 * RR_j_2)

            RR_j_1 = prev_1_label_pos - prev_2_label_pos
            start_prev_1 = int(int(filtered_labels[j-1][0]) - 0.6 * RR_j_1)
            end_prev_1  = int(int(filtered_labels[j-1][0]) + 0.8 * RR_j_1)
            
            RR_j = label_pos - prev_1_label_pos
            start_curr = int(int(filtered_labels[j][0]) - 0.6 * RR_j)
            end_curr  = int(int(filtered_labels[j][0]) + 0.8 * RR_j)
            

            if start_prev_2 < 0 or end_curr > sig_len:
                continue
            
            X.append([
                *np.fft.fft(zscore_per_beat(signal.resample(signals[start_prev_2:end_prev_2], 256))),
                *np.fft.fft(zscore_per_beat(signal.resample(signals[start_prev_1:end_prev_1], 256))),
                *np.fft.fft(zscore_per_beat(signal.resample(signals[start_curr:end_curr], 256)))
            ])
            y.append(filtered_labels[j][1])

    return X, y

# %%
X, y = process_data(window_size=WINDOW_SIZE)

# %%
# values, counts = np.unique(y, return_counts=True)
# plt.bar(values, counts)
# plt.title('Class Distribution')
# plt.xlabel('Class')
# plt.ylabel('Number of Samples')
# plt.show()

# %%
from collections import Counter

def random_undersample_indices(y, random_state=42):
    rng = np.random.default_rng(random_state)

    classes, counts = np.unique(y, return_counts=True)
    min_count = counts.min()

    indices = []
    for c in classes:
        class_idx = np.where(y == c)[0]
        sampled_idx = rng.choice(class_idx, size=min_count, replace=False)
        indices.append(sampled_idx)

    return np.concatenate(indices)

# %%
mlflow.end_run()

# %%
for i in range(5):
    X, y = process_data(window_size=WINDOW_SIZE)
    
    mlflow.start_run()
    mlflow.set_experiment("CVNN_ECG_Classification-Detrend_and_Butterworth_ComplexBatch_ZScore_RelativeWindow_v2")
    mlflow.log_param("model", "CVNN-128-ComplexDense-128-ComplexDense")
    mlflow.log_param("input_dim", (256*3,))
    mlflow.log_param("epochs", EPOCHS)
    mlflow.log_param("batch_size", BATCH_SIZE)
    mlflow.log_param("optimizer", "adam")
    mlflow.log_param("loss", "categorical_crossentropy")
    mlflow.log_param("test_size", TEST_SIZE)
    mlflow.log_param("scaler", "ComplexBatch ZScore")
    mlflow.log_param("classes", "A,L,N,R,V")
    mlflow.log_param("window_size", 256)
    
    # Train/test Split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=42)

    #Label Binarization
    lb = preprocessing.LabelBinarizer()
    y_train = lb.fit_transform(y_train)
    y_test = lb.transform(y_test)

    # # #Under sampling
    y_train_int = np.argmax(y_train, axis=1)
    idx = random_undersample_indices(y_train_int)
    X_train = np.array(X_train)[idx]
    y_train = np.array(y_train)[idx]
    
    model = Sequential()
    model.add(complex_layers.ComplexInput(input_shape=(int(256*3),), name='InputLayer'))
    model.add(complex_layers.ComplexBatchNormalization())

    model.add(complex_layers.ComplexDense(128, activation='cart_relu', name='HiddenLayer-1'))
    model.add(complex_layers.ComplexBatchNormalization())

    model.add(complex_layers.ComplexDense(128, activation='cart_relu', name='HiddenLayer-2'))
    model.add(complex_layers.ComplexBatchNormalization())

    model.add(complex_layers.ComplexDense(5, activation='convert_to_real_with_abs', name='OutputLayer'))
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
        loss='categorical_crossentropy',
        metrics=['accuracy'])
    
    history = model.fit(X_train, y_train, epochs=EPOCHS)
    
    X_test_tf = convert_to_tensor(X_test, dtype=complex64)
    y_test_tf = convert_to_tensor(y_test)
    # X_test_tf = expand_dims(X_test_tf, axis=-1)

    y_pred = np.argmax(model.predict(X_test_tf), axis=1)
    y_true = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(y_true, y_pred)

    precision, recall, f1, support = precision_recall_fscore_support(
        y_true, y_pred, average=None
    )

    precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(
        y_true, y_pred, average="macro"
    )

    precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(
        y_true, y_pred, average="weighted"
    )

    mlflow.log_metric("accuracy", accuracy)

    mlflow.log_metric("precision_macro", precision_macro)
    mlflow.log_metric("recall_macro", recall_macro)
    mlflow.log_metric("f1_macro", f1_macro)

    mlflow.log_metric("precision_weighted", precision_weighted)
    mlflow.log_metric("recall_weighted", recall_weighted)
    mlflow.log_metric("f1_weighted", f1_weighted)

    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm / cm.sum(axis=1, keepdims=True)

    plt.figure(figsize=(7, 6))
    sns.heatmap(
        cm_norm,
        annot=True,
        fmt=".2f",
        cmap="Blues"
    )
    plt.title("Normalized Confusion Matrix")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

    plt.tight_layout()
    plt.savefig("confusion_matrix.png")
    plt.close()

    mlflow.log_artifact("confusion_matrix.png")
    report = classification_report(y_true, y_pred)
    with open("classification_report.txt", "w") as f:
        f.write(report)
    mlflow.log_artifact("classification_report.txt")
    mlflow.end_run()
# Out:
# 2026/01/05 17:38:02 INFO mlflow.tracking.fluent: Experiment with name 'CVNN_ECG_Classification-Detrend_and_Butterworth_ComplexBatch_ZScore_RelativeWindow_v2' does not exist. Creating a new experiment.
# Epoch 1/100
# 307/307 [==============================] - 9s 18ms/step - loss: 0.8296 - accuracy: 0.8053
# Epoch 2/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.5392 - accuracy: 0.9176
# Epoch 3/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.4497 - accuracy: 0.9381
# Epoch 4/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.4022 - accuracy: 0.9506
# Epoch 5/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.3737 - accuracy: 0.9494
# Epoch 6/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.3343 - accuracy: 0.9596
# Epoch 7/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.3206 - accuracy: 0.9611
# Epoch 8/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.2989 - accuracy: 0.9617
# Epoch 9/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.2867 - accuracy: 0.9638
# Epoch 10/100
# 307/307 [==============================] - 6s 18ms/step - loss: 0.2634 - accuracy: 0.9673
# Epoch 11/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.2569 - accuracy: 0.9684
# Epoch 12/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.2585 - accuracy: 0.9667
# Epoch 13/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.2401 - accuracy: 0.9698
# Epoch 14/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.2236 - accuracy: 0.9730
# Epoch 15/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.2212 - accuracy: 0.9741
# Epoch 16/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.2103 - accuracy: 0.9741
# Epoch 17/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.2050 - accuracy: 0.9740
# Epoch 18/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1879 - accuracy: 0.9794
# Epoch 19/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1909 - accuracy: 0.9755
# Epoch 20/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1876 - accuracy: 0.9776
# Epoch 21/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1862 - accuracy: 0.9775
# Epoch 22/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1760 - accuracy: 0.9800
# Epoch 23/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1740 - accuracy: 0.9803
# Epoch 24/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1717 - accuracy: 0.9815
# Epoch 25/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1706 - accuracy: 0.9809
# Epoch 26/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1593 - accuracy: 0.9837
# Epoch 27/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1677 - accuracy: 0.9789
# Epoch 28/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1584 - accuracy: 0.9823
# Epoch 29/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1733 - accuracy: 0.9830
# Epoch 30/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1672 - accuracy: 0.9830
# Epoch 31/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1562 - accuracy: 0.9815
# Epoch 32/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1506 - accuracy: 0.9834
# Epoch 33/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1459 - accuracy: 0.9852
# Epoch 34/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1536 - accuracy: 0.9840
# Epoch 35/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1427 - accuracy: 0.9855
# Epoch 36/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1610 - accuracy: 0.9812
# Epoch 37/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1372 - accuracy: 0.9879
# Epoch 38/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1455 - accuracy: 0.9863
# Epoch 39/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1488 - accuracy: 0.9848
# Epoch 40/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1327 - accuracy: 0.9897
# Epoch 41/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1272 - accuracy: 0.9886
# Epoch 42/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1259 - accuracy: 0.9891
# Epoch 43/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1213 - accuracy: 0.9900
# Epoch 44/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1292 - accuracy: 0.9883
# Epoch 45/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1339 - accuracy: 0.9861
# Epoch 46/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1359 - accuracy: 0.9873
# Epoch 47/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.1328 - accuracy: 0.9880
# Epoch 48/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1319 - accuracy: 0.9859
# Epoch 49/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1294 - accuracy: 0.9880
# Epoch 50/100
# 307/307 [==============================] - 17s 55ms/step - loss: 0.1243 - accuracy: 0.9904
# Epoch 51/100
# 307/307 [==============================] - 142s 459ms/step - loss: 0.1247 - accuracy: 0.9889
# Epoch 52/100
# 307/307 [==============================] - 101s 330ms/step - loss: 0.1174 - accuracy: 0.9917
# Epoch 53/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1180 - accuracy: 0.9911
# Epoch 54/100
# 307/307 [==============================] - 9s 29ms/step - loss: 0.1169 - accuracy: 0.9904
# Epoch 55/100
# 307/307 [==============================] - 7s 23ms/step - loss: 0.1139 - accuracy: 0.9921
# Epoch 56/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1198 - accuracy: 0.9911
# Epoch 57/100
# 307/307 [==============================] - 7s 23ms/step - loss: 0.1241 - accuracy: 0.9888
# Epoch 58/100
# 307/307 [==============================] - 7s 23ms/step - loss: 0.1142 - accuracy: 0.9912
# Epoch 59/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1078 - accuracy: 0.9931
# Epoch 60/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1096 - accuracy: 0.9927
# Epoch 61/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1123 - accuracy: 0.9923
# Epoch 62/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1092 - accuracy: 0.9931
# Epoch 63/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1113 - accuracy: 0.9916
# Epoch 64/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1076 - accuracy: 0.9934
# Epoch 65/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1075 - accuracy: 0.9933
# Epoch 66/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1103 - accuracy: 0.9925
# Epoch 67/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1119 - accuracy: 0.9912
# Epoch 68/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1189 - accuracy: 0.9903
# Epoch 69/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1122 - accuracy: 0.9910
# Epoch 70/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1067 - accuracy: 0.9917
# Epoch 71/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1037 - accuracy: 0.9945
# Epoch 72/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1054 - accuracy: 0.9922
# Epoch 73/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1192 - accuracy: 0.9891
# Epoch 74/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1126 - accuracy: 0.9909
# Epoch 75/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1427 - accuracy: 0.9849
# Epoch 76/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1196 - accuracy: 0.9909
# Epoch 77/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1101 - accuracy: 0.9915
# Epoch 78/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1069 - accuracy: 0.9943
# Epoch 79/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1055 - accuracy: 0.9930
# Epoch 80/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0989 - accuracy: 0.9939
# Epoch 81/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1002 - accuracy: 0.9938
# Epoch 82/100
# 307/307 [==============================] - 6s 18ms/step - loss: 0.1004 - accuracy: 0.9928
# Epoch 83/100
# 307/307 [==============================] - 6s 18ms/step - loss: 0.0994 - accuracy: 0.9942
# Epoch 84/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0996 - accuracy: 0.9940
# Epoch 85/100
# 307/307 [==============================] - 6s 18ms/step - loss: 0.0967 - accuracy: 0.9944
# Epoch 86/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0914 - accuracy: 0.9959
# Epoch 87/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.0988 - accuracy: 0.9934
# Epoch 88/100
# 307/307 [==============================] - 6s 18ms/step - loss: 0.0961 - accuracy: 0.9948
# Epoch 89/100
# 307/307 [==============================] - 6s 18ms/step - loss: 0.0987 - accuracy: 0.9936
# Epoch 90/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.0974 - accuracy: 0.9948
# Epoch 91/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1037 - accuracy: 0.9931
# Epoch 92/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1001 - accuracy: 0.9941
# Epoch 93/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1005 - accuracy: 0.9936
# Epoch 94/100
# 307/307 [==============================] - 6s 18ms/step - loss: 0.1011 - accuracy: 0.9932
# Epoch 95/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1135 - accuracy: 0.9906
# Epoch 96/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1087 - accuracy: 0.9905
# Epoch 97/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.0969 - accuracy: 0.9929
# Epoch 98/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.0973 - accuracy: 0.9935
# Epoch 99/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.0952 - accuracy: 0.9954
# Epoch 100/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1026 - accuracy: 0.9934
# 781/781 [==============================] - 6s 7ms/step
# Epoch 1/100
# 307/307 [==============================] - 9s 20ms/step - loss: 0.8433 - accuracy: 0.8010
# Epoch 2/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.5744 - accuracy: 0.9017
# Epoch 3/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.4869 - accuracy: 0.9246
# Epoch 4/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.4325 - accuracy: 0.9396
# Epoch 5/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.4031 - accuracy: 0.9460
# Epoch 6/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.3650 - accuracy: 0.9546
# Epoch 7/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.3422 - accuracy: 0.9557
# Epoch 8/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.3226 - accuracy: 0.9617
# Epoch 9/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.3025 - accuracy: 0.9638
# Epoch 10/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.2760 - accuracy: 0.9680
# Epoch 11/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.2667 - accuracy: 0.9659
# Epoch 12/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.2706 - accuracy: 0.9641
# Epoch 13/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.2532 - accuracy: 0.9670
# Epoch 14/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.2387 - accuracy: 0.9693
# Epoch 15/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.2316 - accuracy: 0.9721
# Epoch 16/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.2234 - accuracy: 0.9686
# Epoch 17/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.2098 - accuracy: 0.9748
# Epoch 18/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.2068 - accuracy: 0.9765
# Epoch 19/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1940 - accuracy: 0.9773
# Epoch 20/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1905 - accuracy: 0.9771
# Epoch 21/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1882 - accuracy: 0.9748
# Epoch 22/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1902 - accuracy: 0.9766
# Epoch 23/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1787 - accuracy: 0.9775
# Epoch 24/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1718 - accuracy: 0.9793
# Epoch 25/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1852 - accuracy: 0.9778
# Epoch 26/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1641 - accuracy: 0.9809
# Epoch 27/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1578 - accuracy: 0.9837
# Epoch 28/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1702 - accuracy: 0.9820
# Epoch 29/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1602 - accuracy: 0.9809
# Epoch 30/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1582 - accuracy: 0.9814
# Epoch 31/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1657 - accuracy: 0.9826
# Epoch 32/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1541 - accuracy: 0.9844
# Epoch 33/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1494 - accuracy: 0.9862
# Epoch 34/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1583 - accuracy: 0.9807
# Epoch 35/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1440 - accuracy: 0.9867
# Epoch 36/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1626 - accuracy: 0.9810
# Epoch 37/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1499 - accuracy: 0.9871
# Epoch 38/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1483 - accuracy: 0.9835
# Epoch 39/100
# 307/307 [==============================] - 6s 18ms/step - loss: 0.1513 - accuracy: 0.9826
# Epoch 40/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1428 - accuracy: 0.9855
# Epoch 41/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1345 - accuracy: 0.9869
# Epoch 42/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1394 - accuracy: 0.9869
# Epoch 43/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1483 - accuracy: 0.9853
# Epoch 44/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1425 - accuracy: 0.9858
# Epoch 45/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1505 - accuracy: 0.9846
# Epoch 46/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1330 - accuracy: 0.9885
# Epoch 47/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1334 - accuracy: 0.9883
# Epoch 48/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1329 - accuracy: 0.9879
# Epoch 49/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1260 - accuracy: 0.9898
# Epoch 50/100
# 307/307 [==============================] - 6s 18ms/step - loss: 0.1248 - accuracy: 0.9898
# Epoch 51/100
# 307/307 [==============================] - 6s 18ms/step - loss: 0.1264 - accuracy: 0.9892
# Epoch 52/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1289 - accuracy: 0.9886
# Epoch 53/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1295 - accuracy: 0.9886
# Epoch 54/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1270 - accuracy: 0.9888
# Epoch 55/100
# 307/307 [==============================] - 6s 18ms/step - loss: 0.1298 - accuracy: 0.9883
# Epoch 56/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1245 - accuracy: 0.9892
# Epoch 57/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1259 - accuracy: 0.9889
# Epoch 58/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1242 - accuracy: 0.9887
# Epoch 59/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1181 - accuracy: 0.9914
# Epoch 60/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1142 - accuracy: 0.9916
# Epoch 61/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1152 - accuracy: 0.9921
# Epoch 62/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1174 - accuracy: 0.9917
# Epoch 63/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1187 - accuracy: 0.9909
# Epoch 64/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1174 - accuracy: 0.9927
# Epoch 65/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1178 - accuracy: 0.9911
# Epoch 66/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1153 - accuracy: 0.9917
# Epoch 67/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1174 - accuracy: 0.9912
# Epoch 68/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1166 - accuracy: 0.9913
# Epoch 69/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1153 - accuracy: 0.9906
# Epoch 70/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1120 - accuracy: 0.9929
# Epoch 71/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1072 - accuracy: 0.9926
# Epoch 72/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1098 - accuracy: 0.9918
# Epoch 73/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1102 - accuracy: 0.9903
# Epoch 74/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1170 - accuracy: 0.9904
# Epoch 75/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1226 - accuracy: 0.9911
# Epoch 76/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1120 - accuracy: 0.9927
# Epoch 77/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1190 - accuracy: 0.9910
# Epoch 78/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1118 - accuracy: 0.9924
# Epoch 79/100
# 307/307 [==============================] - 6s 18ms/step - loss: 0.1089 - accuracy: 0.9926
# Epoch 80/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1164 - accuracy: 0.9913
# Epoch 81/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1180 - accuracy: 0.9882
# Epoch 82/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1117 - accuracy: 0.9932
# Epoch 83/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1086 - accuracy: 0.9942
# Epoch 84/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1081 - accuracy: 0.9941
# Epoch 85/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1112 - accuracy: 0.9911
# Epoch 86/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1106 - accuracy: 0.9925
# Epoch 87/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1101 - accuracy: 0.9935
# Epoch 88/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1064 - accuracy: 0.9927
# Epoch 89/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1066 - accuracy: 0.9942
# Epoch 90/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1022 - accuracy: 0.9937
# Epoch 91/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1001 - accuracy: 0.9940
# Epoch 92/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1011 - accuracy: 0.9946
# Epoch 93/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1037 - accuracy: 0.9931
# Epoch 94/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1031 - accuracy: 0.9933
# Epoch 95/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.0991 - accuracy: 0.9943
# Epoch 96/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1036 - accuracy: 0.9934
# Epoch 97/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1006 - accuracy: 0.9950
# Epoch 98/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1011 - accuracy: 0.9925
# Epoch 99/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0972 - accuracy: 0.9952
# Epoch 100/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1005 - accuracy: 0.9938
# 781/781 [==============================] - 6s 7ms/step
# Epoch 1/100
# 307/307 [==============================] - 11s 23ms/step - loss: 0.8283 - accuracy: 0.8074
# Epoch 2/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.5617 - accuracy: 0.9067
# Epoch 3/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.4937 - accuracy: 0.9247
# Epoch 4/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.4334 - accuracy: 0.9361
# Epoch 5/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.3885 - accuracy: 0.9487
# Epoch 6/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.3490 - accuracy: 0.9568
# Epoch 7/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.3229 - accuracy: 0.9581
# Epoch 8/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.3146 - accuracy: 0.9605
# Epoch 9/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.2991 - accuracy: 0.9624
# Epoch 10/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.2769 - accuracy: 0.9656
# Epoch 11/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.2647 - accuracy: 0.9696
# Epoch 12/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.2544 - accuracy: 0.9692
# Epoch 13/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.2490 - accuracy: 0.9701
# Epoch 14/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.2420 - accuracy: 0.9709
# Epoch 15/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.2358 - accuracy: 0.9698
# Epoch 16/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.2322 - accuracy: 0.9714
# Epoch 17/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.2240 - accuracy: 0.9753
# Epoch 18/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.2147 - accuracy: 0.9764
# Epoch 19/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1988 - accuracy: 0.9760
# Epoch 20/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.2013 - accuracy: 0.9761
# Epoch 21/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1921 - accuracy: 0.9755
# Epoch 22/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1871 - accuracy: 0.9784
# Epoch 23/100
# 307/307 [==============================] - 7s 23ms/step - loss: 0.1747 - accuracy: 0.9809
# Epoch 24/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1779 - accuracy: 0.9808
# Epoch 25/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1813 - accuracy: 0.9786
# Epoch 26/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1770 - accuracy: 0.9795
# Epoch 27/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1696 - accuracy: 0.9801
# Epoch 28/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1647 - accuracy: 0.9833
# Epoch 29/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1578 - accuracy: 0.9844
# Epoch 30/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1577 - accuracy: 0.9836
# Epoch 31/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1575 - accuracy: 0.9827
# Epoch 32/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1528 - accuracy: 0.9844
# Epoch 33/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1606 - accuracy: 0.9839
# Epoch 34/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1652 - accuracy: 0.9827
# Epoch 35/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1504 - accuracy: 0.9856
# Epoch 36/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1427 - accuracy: 0.9877
# Epoch 37/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1447 - accuracy: 0.9848
# Epoch 38/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1446 - accuracy: 0.9872
# Epoch 39/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1415 - accuracy: 0.9857
# Epoch 40/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1415 - accuracy: 0.9861
# Epoch 41/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1363 - accuracy: 0.9875
# Epoch 42/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1411 - accuracy: 0.9851
# Epoch 43/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1491 - accuracy: 0.9852
# Epoch 44/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1437 - accuracy: 0.9871
# Epoch 45/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1457 - accuracy: 0.9844
# Epoch 46/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1369 - accuracy: 0.9866
# Epoch 47/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.1337 - accuracy: 0.9876
# Epoch 48/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1441 - accuracy: 0.9878
# Epoch 49/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1367 - accuracy: 0.9863
# Epoch 50/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1353 - accuracy: 0.9883
# Epoch 51/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1289 - accuracy: 0.9885
# Epoch 52/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1307 - accuracy: 0.9880
# Epoch 53/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1294 - accuracy: 0.9890
# Epoch 54/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1285 - accuracy: 0.9876
# Epoch 55/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1229 - accuracy: 0.9897
# Epoch 56/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1294 - accuracy: 0.9889
# Epoch 57/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1265 - accuracy: 0.9888
# Epoch 58/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1273 - accuracy: 0.9889
# Epoch 59/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1243 - accuracy: 0.9875
# Epoch 60/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1237 - accuracy: 0.9901
# Epoch 61/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1215 - accuracy: 0.9903
# Epoch 62/100
# 307/307 [==============================] - 7s 23ms/step - loss: 0.1165 - accuracy: 0.9917
# Epoch 63/100
# 307/307 [==============================] - 7s 24ms/step - loss: 0.1204 - accuracy: 0.9900
# Epoch 64/100
# 307/307 [==============================] - 7s 23ms/step - loss: 0.1191 - accuracy: 0.9909
# Epoch 65/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1162 - accuracy: 0.9906
# Epoch 66/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1136 - accuracy: 0.9912
# Epoch 67/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1208 - accuracy: 0.9900
# Epoch 68/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1109 - accuracy: 0.9920
# Epoch 69/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1145 - accuracy: 0.9914
# Epoch 70/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1107 - accuracy: 0.9920
# Epoch 71/100
# 307/307 [==============================] - 7s 23ms/step - loss: 0.1135 - accuracy: 0.9915
# Epoch 72/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1173 - accuracy: 0.9906
# Epoch 73/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1144 - accuracy: 0.9908
# Epoch 74/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1096 - accuracy: 0.9935
# Epoch 75/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1125 - accuracy: 0.9926
# Epoch 76/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1134 - accuracy: 0.9924
# Epoch 77/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1137 - accuracy: 0.9907
# Epoch 78/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1115 - accuracy: 0.9909
# Epoch 79/100
# 307/307 [==============================] - 7s 23ms/step - loss: 0.1134 - accuracy: 0.9911
# Epoch 80/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1118 - accuracy: 0.9911
# Epoch 81/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1088 - accuracy: 0.9920
# Epoch 82/100
# 307/307 [==============================] - 7s 23ms/step - loss: 0.1031 - accuracy: 0.9933
# Epoch 83/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1053 - accuracy: 0.9939
# Epoch 84/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1024 - accuracy: 0.9935
# Epoch 85/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1040 - accuracy: 0.9927
# Epoch 86/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1101 - accuracy: 0.9918
# Epoch 87/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1071 - accuracy: 0.9939
# Epoch 88/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1101 - accuracy: 0.9920
# Epoch 89/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1084 - accuracy: 0.9922
# Epoch 90/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1013 - accuracy: 0.9942
# Epoch 91/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0985 - accuracy: 0.9944
# Epoch 92/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1002 - accuracy: 0.9938
# Epoch 93/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1118 - accuracy: 0.9928
# Epoch 94/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1129 - accuracy: 0.9927
# Epoch 95/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1166 - accuracy: 0.9915
# Epoch 96/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1071 - accuracy: 0.9931
# Epoch 97/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1067 - accuracy: 0.9931
# Epoch 98/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1077 - accuracy: 0.9918
# Epoch 99/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1057 - accuracy: 0.9925
# Epoch 100/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1023 - accuracy: 0.9928
# 781/781 [==============================] - 6s 7ms/step
# Epoch 1/100
# 307/307 [==============================] - 10s 23ms/step - loss: 0.8596 - accuracy: 0.7982
# Epoch 2/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.5699 - accuracy: 0.9119
# Epoch 3/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.4807 - accuracy: 0.9308
# Epoch 4/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.4254 - accuracy: 0.9399
# Epoch 5/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.3929 - accuracy: 0.9476
# Epoch 6/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.3634 - accuracy: 0.9517
# Epoch 7/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.3325 - accuracy: 0.9596
# Epoch 8/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.3067 - accuracy: 0.9620
# Epoch 9/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.2912 - accuracy: 0.9619
# Epoch 10/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.2761 - accuracy: 0.9674
# Epoch 11/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.2667 - accuracy: 0.9653
# Epoch 12/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.2501 - accuracy: 0.9684
# Epoch 13/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.2403 - accuracy: 0.9695
# Epoch 14/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.2375 - accuracy: 0.9695
# Epoch 15/100
# 307/307 [==============================] - 7s 23ms/step - loss: 0.2303 - accuracy: 0.9713
# Epoch 16/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.2252 - accuracy: 0.9738
# Epoch 17/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.2147 - accuracy: 0.9708
# Epoch 18/100
# 307/307 [==============================] - 7s 23ms/step - loss: 0.2067 - accuracy: 0.9764
# Epoch 19/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1949 - accuracy: 0.9784
# Epoch 20/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1879 - accuracy: 0.9797
# Epoch 21/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1944 - accuracy: 0.9767
# Epoch 22/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1893 - accuracy: 0.9770
# Epoch 23/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1846 - accuracy: 0.9794
# Epoch 24/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1775 - accuracy: 0.9796
# Epoch 25/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1714 - accuracy: 0.9800
# Epoch 26/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1702 - accuracy: 0.9831
# Epoch 27/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1764 - accuracy: 0.9798
# Epoch 28/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1681 - accuracy: 0.9805
# Epoch 29/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1641 - accuracy: 0.9824
# Epoch 30/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1609 - accuracy: 0.9829
# Epoch 31/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1584 - accuracy: 0.9827
# Epoch 32/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1570 - accuracy: 0.9847
# Epoch 33/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1533 - accuracy: 0.9835
# Epoch 34/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1510 - accuracy: 0.9846
# Epoch 35/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1522 - accuracy: 0.9845
# Epoch 36/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1455 - accuracy: 0.9867
# Epoch 37/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1464 - accuracy: 0.9847
# Epoch 38/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1660 - accuracy: 0.9802
# Epoch 39/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1416 - accuracy: 0.9868
# Epoch 40/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1393 - accuracy: 0.9873
# Epoch 41/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1502 - accuracy: 0.9852
# Epoch 42/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1532 - accuracy: 0.9842
# Epoch 43/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1369 - accuracy: 0.9881
# Epoch 44/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1356 - accuracy: 0.9883
# Epoch 45/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1406 - accuracy: 0.9890
# Epoch 46/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1317 - accuracy: 0.9886
# Epoch 47/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1294 - accuracy: 0.9875
# Epoch 48/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1366 - accuracy: 0.9866
# Epoch 49/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1318 - accuracy: 0.9889
# Epoch 50/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1259 - accuracy: 0.9898
# Epoch 51/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1216 - accuracy: 0.9907
# Epoch 52/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1234 - accuracy: 0.9888
# Epoch 53/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1274 - accuracy: 0.9889
# Epoch 54/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1311 - accuracy: 0.9892
# Epoch 55/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1273 - accuracy: 0.9885
# Epoch 56/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1291 - accuracy: 0.9907
# Epoch 57/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1260 - accuracy: 0.9905
# Epoch 58/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1260 - accuracy: 0.9903
# Epoch 59/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1345 - accuracy: 0.9866
# Epoch 60/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1218 - accuracy: 0.9908
# Epoch 61/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1186 - accuracy: 0.9925
# Epoch 62/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1162 - accuracy: 0.9926
# Epoch 63/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1140 - accuracy: 0.9935
# Epoch 64/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1166 - accuracy: 0.9917
# Epoch 65/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1172 - accuracy: 0.9920
# Epoch 66/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1083 - accuracy: 0.9943
# Epoch 67/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1220 - accuracy: 0.9918
# Epoch 68/100
# 307/307 [==============================] - 7s 23ms/step - loss: 0.1302 - accuracy: 0.9896
# Epoch 69/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1252 - accuracy: 0.9913
# Epoch 70/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1213 - accuracy: 0.9902
# Epoch 71/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1228 - accuracy: 0.9891
# Epoch 72/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1186 - accuracy: 0.9920
# Epoch 73/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1253 - accuracy: 0.9900
# Epoch 74/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1065 - accuracy: 0.9935
# Epoch 75/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1176 - accuracy: 0.9917
# Epoch 76/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1128 - accuracy: 0.9917
# Epoch 77/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1123 - accuracy: 0.9927
# Epoch 78/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1139 - accuracy: 0.9905
# Epoch 79/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1125 - accuracy: 0.9904
# Epoch 80/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1132 - accuracy: 0.9905
# Epoch 81/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1095 - accuracy: 0.9913
# Epoch 82/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1139 - accuracy: 0.9923
# Epoch 83/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1214 - accuracy: 0.9915
# Epoch 84/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1035 - accuracy: 0.9948
# Epoch 85/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1102 - accuracy: 0.9924
# Epoch 86/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1191 - accuracy: 0.9924
# Epoch 87/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1120 - accuracy: 0.9929
# Epoch 88/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1085 - accuracy: 0.9933
# Epoch 89/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1060 - accuracy: 0.9928
# Epoch 90/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0985 - accuracy: 0.9952
# Epoch 91/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1017 - accuracy: 0.9945
# Epoch 92/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0990 - accuracy: 0.9943
# Epoch 93/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1057 - accuracy: 0.9930
# Epoch 94/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0987 - accuracy: 0.9938
# Epoch 95/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1030 - accuracy: 0.9928
# Epoch 96/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1184 - accuracy: 0.9891
# Epoch 97/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1029 - accuracy: 0.9931
# Epoch 98/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1028 - accuracy: 0.9936
# Epoch 99/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0995 - accuracy: 0.9944
# Epoch 100/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1106 - accuracy: 0.9918
# 781/781 [==============================] - 6s 7ms/step
# Epoch 1/100
# 307/307 [==============================] - 10s 22ms/step - loss: 0.8300 - accuracy: 0.8121
# Epoch 2/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.5454 - accuracy: 0.9133
# Epoch 3/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.4689 - accuracy: 0.9328
# Epoch 4/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.4100 - accuracy: 0.9431
# Epoch 5/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.3668 - accuracy: 0.9525
# Epoch 6/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.3853 - accuracy: 0.9489
# Epoch 7/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.3337 - accuracy: 0.9558
# Epoch 8/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.3047 - accuracy: 0.9597
# Epoch 9/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.2906 - accuracy: 0.9636
# Epoch 10/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.2728 - accuracy: 0.9679
# Epoch 11/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.2755 - accuracy: 0.9652
# Epoch 12/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.2617 - accuracy: 0.9656
# Epoch 13/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.2441 - accuracy: 0.9692
# Epoch 14/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.2303 - accuracy: 0.9715
# Epoch 15/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.2194 - accuracy: 0.9744
# Epoch 16/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.2154 - accuracy: 0.9730
# Epoch 17/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.2150 - accuracy: 0.9717
# Epoch 18/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1950 - accuracy: 0.9793
# Epoch 19/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1910 - accuracy: 0.9776
# Epoch 20/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1923 - accuracy: 0.9772
# Epoch 21/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1978 - accuracy: 0.9773
# Epoch 22/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1895 - accuracy: 0.9814
# Epoch 23/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1864 - accuracy: 0.9806
# Epoch 24/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1750 - accuracy: 0.9819
# Epoch 25/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1690 - accuracy: 0.9823
# Epoch 26/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1590 - accuracy: 0.9838
# Epoch 27/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1648 - accuracy: 0.9823
# Epoch 28/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1635 - accuracy: 0.9842
# Epoch 29/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1660 - accuracy: 0.9804
# Epoch 30/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1582 - accuracy: 0.9827
# Epoch 31/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1568 - accuracy: 0.9844
# Epoch 32/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1504 - accuracy: 0.9866
# Epoch 33/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1539 - accuracy: 0.9847
# Epoch 34/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1466 - accuracy: 0.9855
# Epoch 35/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1519 - accuracy: 0.9846
# Epoch 36/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1618 - accuracy: 0.9854
# Epoch 37/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1420 - accuracy: 0.9875
# Epoch 38/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1397 - accuracy: 0.9888
# Epoch 39/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1372 - accuracy: 0.9896
# Epoch 40/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1440 - accuracy: 0.9854
# Epoch 41/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1342 - accuracy: 0.9879
# Epoch 42/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1398 - accuracy: 0.9872
# Epoch 43/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1468 - accuracy: 0.9852
# Epoch 44/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1334 - accuracy: 0.9879
# Epoch 45/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1475 - accuracy: 0.9857
# Epoch 46/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1326 - accuracy: 0.9888
# Epoch 47/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1380 - accuracy: 0.9885
# Epoch 48/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1353 - accuracy: 0.9871
# Epoch 49/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1297 - accuracy: 0.9887
# Epoch 50/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1392 - accuracy: 0.9887
# Epoch 51/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1283 - accuracy: 0.9885
# Epoch 52/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1205 - accuracy: 0.9907
# Epoch 53/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1177 - accuracy: 0.9934
# Epoch 54/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1202 - accuracy: 0.9925
# Epoch 55/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1245 - accuracy: 0.9909
# Epoch 56/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1232 - accuracy: 0.9922
# Epoch 57/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1186 - accuracy: 0.9917
# Epoch 58/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1226 - accuracy: 0.9899
# Epoch 59/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1196 - accuracy: 0.9908
# Epoch 60/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1229 - accuracy: 0.9897
# Epoch 61/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1150 - accuracy: 0.9917
# Epoch 62/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1205 - accuracy: 0.9923
# Epoch 63/100
# 307/307 [==============================] - 7s 22ms/step - loss: 0.1154 - accuracy: 0.9924
# Epoch 64/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1155 - accuracy: 0.9912
# Epoch 65/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1194 - accuracy: 0.9912
# Epoch 66/100
# 307/307 [==============================] - 7s 21ms/step - loss: 0.1071 - accuracy: 0.9942
# Epoch 67/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1156 - accuracy: 0.9916
# Epoch 68/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1139 - accuracy: 0.9924
# Epoch 69/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1143 - accuracy: 0.9906
# Epoch 70/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1131 - accuracy: 0.9936
# Epoch 71/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1067 - accuracy: 0.9937
# Epoch 72/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1075 - accuracy: 0.9939
# Epoch 73/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1075 - accuracy: 0.9932
# Epoch 74/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1040 - accuracy: 0.9942
# Epoch 75/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.1041 - accuracy: 0.9942
# Epoch 76/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1082 - accuracy: 0.9922
# Epoch 77/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1085 - accuracy: 0.9934
# Epoch 78/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1104 - accuracy: 0.9930
# Epoch 79/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1073 - accuracy: 0.9940
# Epoch 80/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1061 - accuracy: 0.9944
# Epoch 81/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1056 - accuracy: 0.9930
# Epoch 82/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1181 - accuracy: 0.9899
# Epoch 83/100
# 307/307 [==============================] - 6s 19ms/step - loss: 0.1057 - accuracy: 0.9934
# Epoch 84/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1081 - accuracy: 0.9929
# Epoch 85/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1052 - accuracy: 0.9937
# Epoch 86/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1028 - accuracy: 0.9933
# Epoch 87/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0982 - accuracy: 0.9948
# Epoch 88/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1033 - accuracy: 0.9946
# Epoch 89/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1068 - accuracy: 0.9923
# Epoch 90/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1034 - accuracy: 0.9927
# Epoch 91/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1012 - accuracy: 0.9938
# Epoch 92/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1002 - accuracy: 0.9930
# Epoch 93/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1039 - accuracy: 0.9936
# Epoch 94/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1002 - accuracy: 0.9940
# Epoch 95/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0993 - accuracy: 0.9938
# Epoch 96/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.1007 - accuracy: 0.9942
# Epoch 97/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0983 - accuracy: 0.9936
# Epoch 98/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0958 - accuracy: 0.9944
# Epoch 99/100
# 307/307 [==============================] - 6s 21ms/step - loss: 0.0965 - accuracy: 0.9948
# Epoch 100/100
# 307/307 [==============================] - 6s 20ms/step - loss: 0.0980 - accuracy: 0.9949
# 781/781 [==============================] - 7s 8ms/step

# %%
experiment_name = "CVNN_ECG_Classification-Detrend_and_Butterworth_ComplexBatch_ZScore_RelativeWindow_v2"

runs = mlflow.search_runs(
    experiment_names=[experiment_name],
    output_format="pandas"
)

summary = (
    runs
    .groupby(["params.window_size", "params.epochs", "params.model"])
    .agg(
        accuracy_mean=("metrics.accuracy", "mean"),
        accuracy_std=("metrics.accuracy", "std"),
        f1_macro_mean=("metrics.f1_macro", "mean"),
        f1_macro_std=("metrics.f1_macro", "std"),
    )
    .reset_index()
)

print(summary)
# Out:
#   params.window_size params.epochs                            params.model  \
# 0                256           100  CVNN-128-ComplexDense-128-ComplexDense
#
#    accuracy_mean  accuracy_std  f1_macro_mean  f1_macro_std
# 0       0.971496      0.003884       0.926698      0.007777
